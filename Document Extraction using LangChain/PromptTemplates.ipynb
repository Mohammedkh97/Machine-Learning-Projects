# %% [markdown]
# String PromptTemplates

# %%
from langchain_core.prompts import PromptTemplate

prompt_template = PromptTemplate.from_template("Tell me a joke about {topic}")

prompt_template.invoke({"topic": "cats"})
# Out:
# StringPromptValue(text='Tell me a joke about cats')

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt_template = ChatPromptTemplate([
    ("system", "You are a helpful assistant"),
    ("user", "Tell me a joke about {topic}")
])

prompt_result = prompt_template.invoke({"topic": "cats"})
print(prompt_result)
# Print the content of the human message
for msg in prompt_result.messages:
    if msg.__class__.__name__ == "HumanMessage":
        print(msg.content)
# Out:
# messages=[SystemMessage(content='You are a helpful assistant', additional_kwargs={}, response_metadata={}), HumanMessage(content='Tell me a joke about cats', additional_kwargs={}, response_metadata={})]
# Tell me a joke about cats

# %% [markdown]
# ## Document Data Extractor

# %%
import os
path = r"/home/developer/Dev/Machine-Learning-Projects/Employees_Data_Detection/EmployeesData"
os.listdir(path)
# Out:
# ['Contracts',
#  'output_images',
#  'Passport',
#  'Change Status',
#  'رسوم عقد عمل.pdf',
#  'DUBAI INSURANCE COMPANY.pdf',
#  'eVisa',
#  'رسوم زيارة ثانية.pdf',
#  'New Work Entry Permit - Employee',
#  'رسوم تاشيرة عمل.pdf',
#  'Residence',
#  'رسوم تعديل وضع.pdf']

# %%
# Internal folder name
typeFolder = "eVisa"

# Map internal folder names to human-readable names
Folder_Names = {
    "Change Status": "Change_of_Status_Documents",
    "Residence": "Residence_Documents",
    "eVisa Tourism": "Tourism_Visa_Documents",
    "eVisa Employment": "Employment_Visa_Documents",
    "Employment Contract Full Work": "Full_Employment_Contracts",
    "Passport": "Passport_Documents"
}

# %%
import os
import fitz  # PyMuPDF

folder_name = Folder_Names.get(typeFolder, typeFolder)

# Full folder path
folder_path = os.path.join(path, typeFolder)

# %%
# This is a list comprehension in Python. It creates a list of .pdf files found in the folder folder_path.
files = [f for f in os.listdir(folder_path) if f.lower().endswith('.pdf')]
print(files)
# Out:
# ['myVisa.pdf', 'تاشيرة عمل.pdf', 'تاشيرة سياحة.pdf']

# %%
# This is a list comprehension in Python. It creates a list of .pdf files found in the folder folder_path.
files = [f for f in os.listdir(folder_path) if f.lower().endswith('.pdf')]

# Open PDF file ( Indices relate to files number in the above list)
if files:
    pdf_path = os.path.join(folder_path, files[1])
    doc = fitz.open(pdf_path)
    text= doc[0].get_text()
    print(f"Reading from: {folder_name}")
    print(text)
else:
    print(f"No PDF files found in: {folder_path}")
# Out:
# Reading from: eVisa
# ﺁﻣﺮ ﺑﺨﺪﻣﺔ ﺍﻹﺗﺼﺎﻝ ﻳﺮﺟﻲ ,ﺍﻹﺩﺍﺭﺓ ﻣﻊ ﻟﺘﺘﻮﺍﺻﻞ
# 8005111 / 04-3139999 :ﻫﺎﺗﻒ
# For any inquiry please call AMER SERVICE
# tel : 04-3139999 / 8005111
# ﺍﻷﻣﻴﻦ ﻣﻊ ﺗﻌﺎﻣﻞ ,ﻣﺠﺘﻤﻌﻚ ﻓﻲ ﺁﻣﻨﺎ ﻛﻦ
# A safer neighbourhood is a safer home.
# Toll free 8004888. www.alameen.ae
#
#
# eVisa – ﺇﺫﻥ ﺩﺧﻮﻝ ﺇﻟﻜﺘﺮﻭﻧﻲ
# 22520195577670/1
# *  0  7  0  2  0  1  0  2  2  5  9  4  7  8  6  7  *
# ﻋـﻤـﻞ
# EMPLOYMENT
# ENTRY PERMIT NO :
# 201/2025/2947867
# : ﺭﻗﻢ ﺩﺧﻮﻝ ﺇﺫﻥ
# Date & Place of Issue :
# 25-05-2025  Dubai
#         ﺩﺑﻲ2025-05-25
# : ﺍﻹﺻﺪﺍﺭ ﻭﻣﺤﻞ ﺗﺎﺭﻳﺦ
# Valid Until :
# 23-07-2025
# 2025-07-23
# : ﺍﻟﺪﺧﻮﻝ ﺻﻼﺣﻴﺔ ﺗﺎﺭﻳﺦ
# U.I.D. No. :
# 84193034
# : ﺍﻟﺮﻗﻢ ﺍﻟﻤﻮﺣﺪ
# Allowed to Enter U.A.E to :
# : ﺃﺟﻴﺰ ﺑﺪﺧﻮﻝ ﺩﻭﻟﺔ ﺍﻻﻣﺎﺭﺍﺕ ﺍﻟﻌﺮﺑﻴﺔ ﺍﻟﻤﺘﺤﺪﺓ ﺍﻟﻰ
# Full Name :
# Ms. ANISHA THAPA MAGARﺍﻧﻴﺸﺎ ﺛﺎﺑﺎ ﻣﺎﺟﺎﺭ: ﺍﻻﺳﻢ ﺍﻟﻜﺎﻣﻞ
# Nationality :
# NEPALﻧﻴﺒﺎﻝ: ﺍﻟﺠﻨﺴﻴﺔ
# Place of Birth :
# KASKIﻛﺎﺳﻜﻰ: ﻣﻜﺎﻥ ﺍﻟﻤﻴﻼﺩ
# Date of Birth :
# 26/02/2002
# 2002/02/26
# : ﺗﺎﺭﻳﺦ ﺍﻟﻤﻴﻼﺩ
# Passport No. :
# Normal / PA0272457
# PA0272457 / ﻋﺎﺩﻱ:  ﺭﻗﻢ ﺍﻟﺠﻮﺍﺯ
# Profession :
# NURSE ASSISTANTﻣﺴﺎﻋﺪ ﻣﻤﺮﺽ: ﺍﻟﻤﻬﻨﺔ
# Accompanied by
#
#  ﺍﻟﻤﺮﺍﻓﻘﻮﻥ
# Noneﻻ ﻳﻮﺟﺪ
#
#
#
# Employerﺍﻟﻌﻤﻞ ﺻﺎﺣﺐ
# Name :
# ARYA CLINIC L.L.Cﻋﻴﺎﺩﺓ ﺁﺭﻳﺎ ﺵ.ﺫ.ﻡ.ﻡ : ﺍﻻﺳﻢ
# Address :
# TEL: 043443600 P.O.BOX: 74250 , 2/1/143967
# : ﺍﻟﻌﻨﻮﺍﻥ
# Note :
# The United Arab Emirates welcomes you and wishes you a
# happy stay. Please be sure to change your status or leave
# before the visa expires, so we can welcome you again
#  ﺗﺮﺣﺐ ﺑﻚ ﺩﻭﻟﺔ ﺍﻻﻣﺎﺭﺍﺕ ﺍﻟﻌﺮﺑﻴﺔ ﺍﻟﻤﺘﺤﺪﺓ ﻭﺗﺘﻤﻨﻰ ﻟﻚ ﺇﻗﺎﻣﺔ ﺳﻌﻴﺪﺓ, ﻭﻳﺮﺟﻰ
# ﺍﻟﺘﺄﻛﺪ ﻣﻦ ﺗﻌﺪﻳﻞ ﺍﻟﻮﺿﻊ ﺍﻭ ﺍﻟﻤﻐﺎﺩﺭﺓ ﻗﺒﻞ ﺍﻧﺘﻬﺎﺀ ﻓﺘﺮﺓ ﺻﻼﺣﻴﺔ ﺍﻟﺘﺄﺷﻴﺮﺓ
# ﻟﻨﺘﻤﻜﻦ ﻣﻦ ﺍﻟﺘﺮﺣﻴﺐ ﺑﻚ ﻣﺮﻩ ﺍﺧﺮﻯ
# : ﺗﻨﺒﻴﻪ
# Enjoy Using Smart Gates across Dubai airportsﻳﻤﻜﻨﻚ ﺍﻟﺘﻤﺘﻊ ﺑﺈﺳﺘﺨﺪﺍﻡ ﺍﻟﺒﻮﺍﺑﺎﺕ ﺍﻟﺬﻛﻴﺔ ﻋﺒﺮ ﻣﻄﺎﺭﺍﺕ ﺩﺑﻲ
# ﺍﻹﺩﺍﺭﺓ ﺍﻟﻌﺎﻣﺔ ﻟﻺﻗﺎﻣﺔ ﻭﺷﺆﻭﻥ ﺍﻷﺟﺎﻧﺐGeneral Directorate for Identity & Foreigners Affairs - Dubaiﺍﺳﺘﻮﻓﻴﺖ ﺍﻟﺮﺳﻮﻡ
#  ﺩﺑﻲ- ﺍﻹﺩﺍﺭﺓ ﺍﻟﻌﺎﻣﺔ ﻟﻠﻬﻮﻳﺔ ﻭﺷﺆﻭﻥ ﺍﻷﺟﺎﻧﺐ

# %% [markdown]
# ### LangChain ChatPromptTemplate

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt_template = ChatPromptTemplate([
    ("system", "You are a helpful information extraction system"),
    ("user", 
"""
{document_text}


Please extract and return this data in JSON format with fields and don't miss to mention the document type:
The document type maybe is passport, visa (tourism or employment), change status, employment contract, residence, healthcare professional
if the document is a passport, extract the following fields:
    {{
    "document_type": "Passport",
    "passport_details": [
        {{
            "passport_number": "",
            "name": "",
            "date_of_birth": "DD/MM/YYYY",
            "date_of_issue": "DD/MM/YYYY",
            "date_of_expiry": "DD/MM/YYYY",
            "profession": ""
        }}
    ]
}}
if the document is a visa, extract the following fields:
{{
"document_type": "Visa - [Tourism or Employment]",
"visa_details": [
{{
        "issue_date": "DD/MM/YYYY",
        "place_of_issue": "",
        "valid_until": "DD/MM/YYYY",
        "uid_number": "",
        "full_name": "",
        "nationality": "",
        "place_of_birth": "",
        "date_of_birth": "DD/MM/YYYY",
        "passport_number": "",
        "profession": ""
    }}
]
}}

if the document is a change status, extract the following fields:
    {{
"document_type": "Change Status",
"change_status_details": [
{{
        "uid_number": "",
        "name": "",
        "nationality": "",
        "passport_number": "",
        "profession": "",
        "employer_name": "",
        "residence_stamping_deadline": "DD/MM/YYYY"
        
    }}
]
}}
if the document is an Employment Contract, extract the following fields which related to the employee:
    {{
"document_type": "Employment contract",
"contract_details": [
    {{
        "work_style": "Full Time or Part Time",
        "transaction_number": "",
        "nationality": "",
        "passport_number": "",
        "date_of_birth": "DD/MM/YYYY",
        "academic_qualification": "",
        "contract_start": "DD/MM/YYYY",
        "contract_end": "DD/MM/YYYY"
    }}
]
}}
if the document is a residence, extract the following fields:
    {{
"document_type": "Residence",
"residence_details": [
{{
        "id_number": "",
        "passport_number": "",
        "name": "",
        "issue_date": "DD/MM/YYYY",
        "expiry_date": "DD/MM/YYYY",
        "profession": ""
    }}
]
}}

if healthcare professional registeration certification, extract the following fields:
{{
"document_type": "Healthcare",
"healthcare_certificate_details": [
{{
        "professional_name": "",
        "dha_unique_id": ""
    }}
]
}}
     """
)
])

# %% [markdown]
# ##### In the following cell you will see the **ChatPromptValue**

# %%
prompt_result = prompt_template.invoke({"document_text": text})
prompt_result
# Out:
# ChatPromptValue(messages=[SystemMessage(content='You are a helpful information extraction system', additional_kwargs={}, response_metadata={}), HumanMessage(content='\nﺁﻣﺮ ﺑﺨﺪﻣﺔ ﺍﻹﺗﺼﺎﻝ ﻳﺮﺟﻲ ,ﺍﻹﺩﺍﺭﺓ ﻣﻊ ﻟﺘﺘﻮﺍﺻﻞ\n8005111 / 04-3139999 :ﻫﺎﺗﻒ\nFor any inquiry please call AMER SERVICE\ntel : 04-3139999 / 8005111\nﺍﻷﻣﻴﻦ ﻣﻊ ﺗﻌﺎﻣﻞ ,ﻣﺠﺘﻤﻌﻚ ﻓﻲ ﺁﻣﻨﺎ ﻛﻦ\nA safer neighbourhood is a safer home.\nToll free 8004888. www.alameen.ae\n \n \neVisa – ﺇﺫﻥ ﺩﺧﻮﻝ ﺇﻟﻜﺘﺮﻭﻧﻲ\n22520195577670/1\n*  0  7  0  2  0  1  0  2  2  5  9  4  7  8  6  7  *\nﻋـﻤـﻞ\nEMPLOYMENT\nENTRY PERMIT NO :\n201/2025/2947867\n: ﺭﻗﻢ ﺩﺧﻮﻝ ﺇﺫﻥ \nDate & Place of Issue :\n25-05-2025  Dubai\n        ﺩﺑﻲ2025-05-25\n: ﺍﻹﺻﺪﺍﺭ ﻭﻣﺤﻞ ﺗﺎﺭﻳﺦ\nValid Until :\n23-07-2025 \n2025-07-23\n: ﺍﻟﺪﺧﻮﻝ ﺻﻼﺣﻴﺔ ﺗﺎﺭﻳﺦ\nU.I.D. No. :\n84193034\n: ﺍﻟﺮﻗﻢ ﺍﻟﻤﻮﺣﺪ\nAllowed to Enter U.A.E to :\n: ﺃﺟﻴﺰ ﺑﺪﺧﻮﻝ ﺩﻭﻟﺔ ﺍﻻﻣﺎﺭﺍﺕ ﺍﻟﻌﺮﺑﻴﺔ ﺍﻟﻤﺘﺤﺪﺓ ﺍﻟﻰ\nFull Name :\nMs. ANISHA THAPA MAGARﺍﻧﻴﺸﺎ ﺛﺎﺑﺎ ﻣﺎﺟﺎﺭ: ﺍﻻﺳﻢ ﺍﻟﻜﺎﻣﻞ\nNationality :\nNEPALﻧﻴﺒﺎﻝ: ﺍﻟﺠﻨﺴﻴﺔ\nPlace of Birth :\nKASKIﻛﺎﺳﻜﻰ: ﻣﻜﺎﻥ ﺍﻟﻤﻴﻼﺩ\nDate of Birth :\n26/02/2002\n2002/02/26\n: ﺗﺎﺭﻳﺦ ﺍﻟﻤﻴﻼﺩ\nPassport No. :\nNormal / PA0272457\nPA0272457 / ﻋﺎﺩﻱ:  ﺭﻗﻢ ﺍﻟﺠﻮﺍﺯ\nProfession :\nNURSE ASSISTANTﻣﺴﺎﻋﺪ ﻣﻤﺮﺽ: ﺍﻟﻤﻬﻨﺔ\nAccompanied by\n \n ﺍﻟﻤﺮﺍﻓﻘﻮﻥ \nNoneﻻ ﻳﻮﺟﺪ\n            \n            \n   \nEmployerﺍﻟﻌﻤﻞ ﺻﺎﺣﺐ\nName :\nARYA CLINIC L.L.Cﻋﻴﺎﺩﺓ ﺁﺭﻳﺎ ﺵ.ﺫ.ﻡ.ﻡ : ﺍﻻﺳﻢ\nAddress :\nTEL: 043443600 P.O.BOX: 74250 , 2/1/143967\n: ﺍﻟﻌﻨﻮﺍﻥ\nNote :\nThe United Arab Emirates welcomes you and wishes you a \nhappy stay. Please be sure to change your status or leave \nbefore the visa expires, so we can welcome you again\n ﺗﺮﺣﺐ ﺑﻚ ﺩﻭﻟﺔ ﺍﻻﻣﺎﺭﺍﺕ ﺍﻟﻌﺮﺑﻴﺔ ﺍﻟﻤﺘﺤﺪﺓ ﻭﺗﺘﻤﻨﻰ ﻟﻚ ﺇﻗﺎﻣﺔ ﺳﻌﻴﺪﺓ, ﻭﻳﺮﺟﻰ\nﺍﻟﺘﺄﻛﺪ ﻣﻦ ﺗﻌﺪﻳﻞ ﺍﻟﻮﺿﻊ ﺍﻭ ﺍﻟﻤﻐﺎﺩﺭﺓ ﻗﺒﻞ ﺍﻧﺘﻬﺎﺀ ﻓﺘﺮﺓ ﺻﻼﺣﻴﺔ ﺍﻟﺘﺄﺷﻴﺮﺓ \nﻟﻨﺘﻤﻜﻦ ﻣﻦ ﺍﻟﺘﺮﺣﻴﺐ ﺑﻚ ﻣﺮﻩ ﺍﺧﺮﻯ\n: ﺗﻨﺒﻴﻪ\nEnjoy Using Smart Gates across Dubai airportsﻳﻤﻜﻨﻚ ﺍﻟﺘﻤﺘﻊ ﺑﺈﺳﺘﺨﺪﺍﻡ ﺍﻟﺒﻮﺍﺑﺎﺕ ﺍﻟﺬﻛﻴﺔ ﻋﺒﺮ ﻣﻄﺎﺭﺍﺕ ﺩﺑﻲ\nﺍﻹﺩﺍﺭﺓ ﺍﻟﻌﺎﻣﺔ ﻟﻺﻗﺎﻣﺔ ﻭﺷﺆﻭﻥ ﺍﻷﺟﺎﻧﺐGeneral Directorate for Identity & Foreigners Affairs - Dubaiﺍﺳﺘﻮﻓﻴﺖ ﺍﻟﺮﺳﻮﻡ\n ﺩﺑﻲ- ﺍﻹﺩﺍﺭﺓ ﺍﻟﻌﺎﻣﺔ ﻟﻠﻬﻮﻳﺔ ﻭﺷﺆﻭﻥ ﺍﻷﺟﺎﻧﺐ\n\n\n\nPlease extract and return this data in JSON format with fields and don\'t miss to mention the document type:\nThe document type maybe is passport, visa (tourism or employment), change status, employment contract, residence, healthcare professional\nif the document is a passport, extract the following fields:\n    {\n    "document_type": "Passport",\n    "passport_details": [\n        {\n            "passport_number": "",\n            "name": "",\n            "date_of_birth": "DD/MM/YYYY",\n            "date_of_issue": "DD/MM/YYYY",\n            "date_of_expiry": "DD/MM/YYYY",\n            "profession": ""\n        }\n    ]\n}\nif the document is a visa, extract the following fields:\n{\n"document_type": "Visa - [Tourism or Employment]",\n"visa_details": [\n{\n        "issue_date": "DD/MM/YYYY",\n        "place_of_issue": "",\n        "valid_until": "DD/MM/YYYY",\n        "uid_number": "",\n        "full_name": "",\n        "nationality": "",\n        "place_of_birth": "",\n        "date_of_birth": "DD/MM/YYYY",\n        "passport_number": "",\n        "profession": ""\n    }\n]\n}\n\nif the document is a change status, extract the following fields:\n    {\n"document_type": "Change Status",\n"change_status_details": [\n{\n        "uid_number": "",\n        "name": "",\n        "nationality": "",\n        "passport_number": "",\n        "profession": "",\n        "employer_name": "",\n        "residence_stamping_deadline": "DD/MM/YYYY"\n\n    }\n]\n}\nif the document is an Employment Contract, extract the following fields which related to the employee:\n    {\n"document_type": "Employment contract",\n"contract_details": [\n    {\n        "work_style": "Full Time or Part Time",\n        "transaction_number": "",\n        "nationality": "",\n        "passport_number": "",\n        "date_of_birth": "DD/MM/YYYY",\n        "academic_qualification": "",\n        "contract_start": "DD/MM/YYYY",\n        "contract_end": "DD/MM/YYYY"\n    }\n]\n}\nif the document is a res ...

# %% [markdown]
# ### Load Groq API KEY

# %%
import os
# Import load_dotenv function from python-dotenv package
from dotenv import load_dotenv

# Load environment variables from a .env file into the environment
load_dotenv()
print(os.getenv("GROQ_API_KEY"))  # Should print your key (or part of it)
# Out:
# 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

# %%
# Import the ChatGroq class from langchain_groq library for interacting with Groq's API
from langchain_groq import ChatGroq

# Initialize a ChatGroq instance with the following parameters:
# - model: Using the "deepseek-r1-distill-llama-70b" model
# - temperature: Set to 0.7 (higher values make output more random/creative)
# - max_tokens: Limit the response to 1024 tokens maximum
llm = ChatGroq(
    model="deepseek-r1-distill-llama-70b",
    temperature=0.0,
    max_tokens=1024,
)

# %% [markdown]
# ### Let's see the output after Pass the prompt into Groq LLM:
# - The output is not included specific schema!

# %%
document_text = text  # Extracted Text from the document

# Build the final prompt with your document text
final_prompt = prompt_template.invoke({"document_text": document_text})

# Pass to Groq LLM
response = llm.invoke(final_prompt)

# response.content will have your JSON
for line in response.content.splitlines():
    print(line)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[12], line 7
#       4 final_prompt = prompt_template.invoke({"document_text": document_text})
#       6 # Pass to Groq LLM
# ----> 7 response = llm.invoke(final_prompt)
#       9 # response.content will have your JSON
#      10 for line in response.content.splitlines():
#
# File ~/Dev/Machine-Learning-Projects/Employees_Data_Detection/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:372, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     360 @override
#     361 def invoke(
#     362     self,
#    (...)    367     **kwargs: Any,
#     368 ) -> BaseMessage:
#     369     config = ensure_config(config)
#     370     return cast(
#     371         "ChatGeneration",
# --> 372         self.generate_prompt(
#     373             [self._convert_input(input)],
#     374             stop=stop,
#     375             callbacks=config.get("callbacks"),
#     376             tags=config.get("tags"),
#     377             metadata=config.get("metadata"),
#     378             run_name=config.get("run_name"),
#     379             run_id=config.pop("run_id", None),
#     380             **kwargs,
#     381         ).generations[0][0],
#     382     ).message
#
# File ~/Dev/Machine-Learning-Projects/Employees_Data_Detection/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:957, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     948 @override
#     949 def generate_prompt(
#     950     self,
#    (...)    954     **kwargs: Any,
#     955 ) -> LLMResult:
#     956     prompt_messages = [p.to_messages() for p in prompts]
# --> 957     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Dev/Machine-Learning-Projects/Employees_Data_Detection/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:776, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     773 for i, m in enumerate(input_messages):
#     774     try:
#     775         results.append(
# --> 776             self._generate_with_cache(
#     777                 m,
#     778                 stop=stop,
#     779                 run_manager=run_managers[i] if run_managers else None,
#     780                 **kwargs,
#     781             )
#     782         )
#     783     except BaseException as e:
#     784         if run_managers:
#
# File ~/Dev/Machine-Learning-Projects/Employees_Data_Detection/venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:1022, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1020     result = generate_from_stream(iter(chunks))
#    1021 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1022     result = self._generate(
#    1023         messages, stop=stop, run_manager=run_manager, **kwargs
#    1024     )
#    1025 else:
#    1026     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Dev/Machine-Learning-Projects/Employees_Data_Detection/venv/lib/python3.11/site-packages/langchain_groq/chat_models.py:498, in ChatGroq._generate(self, messages, stop, run_manager, **kwargs)
#     493 message_dicts, params = self._create_message_dicts(messages, stop)
#     494 params = {
#     495     **params,
#     496     **kwargs,
#     497 }
# --> 498 response = self.client.create(messages=message_dicts, **params)
#     499 return self._create_chat_result(response)
#
# File ~/Dev/Machine-Learning-Projects/Employees_Data_Detection/venv/lib/python3.11/site-packages/groq/resources/chat/completions.py:368, in Completions.create(self, messages, model, exclude_domains, frequency_penalty, function_call, functions, include_domains, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, n, parallel_tool_calls, presence_penalty, reasoning_effort, reasoning_format, response_format, search_settings, seed, service_tier, stop, store, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     181 def create(
#     182     self,
#     183     *,
#    (...)    229     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     230 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     231     """
#     232     Creates a model response for the given chat conversation.
#     233
#    (...)    366       timeout: Override the client-level default timeout for this request, in seconds
#     367     """
# --> 368     return self._post(
#     369         "/openai/v1/chat/completions",
#     370         body=maybe_transform(
#     371             {
#     372                 "messages": messages,
#     373                 "model": model,
#     374                 "exclude_domains": exclude_domains,
#     375                 "frequency_penalty": frequency_penalty,
#     376                 "function_call": function_call,
#     377                 "functions": functions,
#     378                 "include_domains": include_domains,
#     379                 "logit_bias": logit_bias,
#     380                 "logprobs": logprobs,
#     381                 "max_completion_tokens": max_completion_tokens,
#     382                 "max_tokens": max_tokens,
#     383                 "metadata": metadata,
#     384                 "n": n,
#     385                 "parallel_tool_calls": parallel_tool_calls,
#     386                 "presence_penalty": presence_penalty,
#     387                 "reasoning_effort": reasoning_effort,
#     388                 "reasoning_format": reasoning_format,
#     389                 "response_format": response_format,
#     390                 "search_settings": search_settings,
#     391                 "seed": seed,
#     392                 "service_tier": service_tier,
#     393                 "stop": stop,
#     394                 "store": store,
#     395                 "stream": stream,
#     396                 "temperature": temperature,
#     397                 "tool_choice": tool_choice,
#     398                 "tools": tools,
#     399                 "top_logprobs": top_logprobs,
#     400                 "top_p": top_p,
#     401                 "user": user,
#     402             },
#     403             completion_create_params.CompletionCreateParams,
#     404         ),
#     405         options=make_request_options(
#     406             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     407         ),
#     408         cast_to=ChatCompletion,
#     409         stream=stream or False,
#     410         stream_cls=Stream[ChatCompletionChunk],
#     411     )
#
# File ~/Dev/Machine-Learning-Projects/Employees_Data_Detection/venv/lib/python3.11/site-packages/groq/_base_client.py:1225, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1211 def post(
#    1212     self,
#    1213     path: str,
#    (...)   1220     stream_cls: type[_StreamT] | None = None,
#    1221 ) -> ResponseT | _StreamT:
#    1222     opts = FinalRequestOptions.construct(
#    1223         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1224     )
# -> 1225     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Dev/Machine-Learning-Projects/Employees_Data_Detection/venv/lib/python3.11/site-packages/groq/_base_client.py:1034, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1031             err.response.read()
#    1033         log.debug("Re-raising status error")
# -> 1034         raise self._make_status_error_from_response(err.response) from None
#    1036     break
#    1038 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Invalid API Key', 'type': 'invalid_request_error', 'code': 'invalid_api_key'}}

# %% [markdown]
# ### After seeing the Output, we need to extract the required data using a specific schema

# %%
from pydantic import BaseModel, Field, ValidationError
from typing import Optional, Union, List
from enum import Enum


class PersonalInfo(str, Enum):
    CONTRACT = "EMPLOYMENT CONTRACT FULL WORK"
    TOURISM_VISA = "eVisa - Tourism"
    EMPLOYMENT_VISA = "eVisa - Employment"
    RESIDENCE = "Residence"
    CHANGE_STATUS = "Change Status"
    HEALTHCARE = "Healthcare Professional Registration Certificate"
    PASSPORT = "Passport"
    
    
class ContractData(BaseModel):
    work_style: Optional[str]
    transaction_number: Optional[str]  # Changed from List[str]
    name: Optional[str]
    nationality: Optional[str]
    passport_number: Optional[str]
    date_of_birth: Optional[str]  # Changed from List[str]
    academic_qualification: Optional[str]
    contract_start: Optional[str]
    contract_end: Optional[str]
    
    
class VisaData(BaseModel):
    issue_date: Optional[str]
    place_of_issue: Optional[str]
    valid_until: Optional[str]
    uid_number: Optional[str]
    full_name: Optional[str]
    nationality: Optional[str]
    place_of_birth: Optional[str]
    date_of_birth: Optional[str]
    passport_number: Optional[str]
    profession: Optional[str]

class ResidenceData(BaseModel):
    id_number: Optional[str]
    passport_number: Optional[str]
    name: Optional[str]
    profession: Optional[str]
    issue_date: Optional[str]
    expiry_date: Optional[str]

class ChangeStatusData(BaseModel):
    uid_number: Optional[str]
    name: Optional[str]
    nationality: Optional[str]
    profession: Optional[str]
    passport_number: Optional[str]
    employer_name: Optional[str]
    residence_stamping_deadline: Optional[str]


class HealthcareRegistrationData(BaseModel):
    professional_name: Optional[str]
    dha_unique_id: Optional[str]


class PassportData(BaseModel):
    passport_number: Optional[str]
    name: Optional[str]
    date_of_birth: Optional[str]
    date_of_issue: Optional[str]
    date_of_expiry: Optional[str]
    profession: Optional[str]

# class DocumentSchema(BaseModel):
#     document_type: PersonalInfo
#     contractDetails: Optional[List[ContractData]] = None
#     visaDetails: Optional[List[VisaData]] = None
#     residenceDetails: Optional[List[ResidenceData]] = None
#     changeStatusDetails: Optional[List[ChangeStatusData]] = None
#     healthcareDetails: Optional[List[HealthcareRegistrationData]] = None
#     passportDetails: Optional[List[PassportData]] = None


class DocumentSchema(BaseModel):
    document_type: PersonalInfo = Field(..., alias="document_type")
    visa_details: Optional[List[VisaData]] = Field(default=None, alias="visa_details")

    class Config:
        allow_population_by_field_name = True
# Out:
# /home/developer/Dev/Machine-Learning-Projects/Employees_Data_Detection/venv/lib/python3.11/site-packages/pydantic/_internal/_config.py:373: UserWarning: Valid config keys have changed in V2:
# * 'allow_population_by_field_name' has been renamed to 'validate_by_name'
#   warnings.warn(message, UserWarning)

# %% [markdown]
# ### Insert a Specific Schema into the structured output of Groq LLM

# %%
structured_llm = llm.with_structured_output(DocumentSchema)

# %%
document_text = text  # Extracted Text from the document
schema_chain = prompt_template | structured_llm

# %%
final_prompt = schema_chain.invoke({"document_text": document_text})

# %%
import json
print(json.dumps(final_prompt.model_dump(), indent=4))
# Out:
# {
#     "document_type": "eVisa - Employment",
#     "visa_details": [
#         {
#             "issue_date": "25/05/2025",
#             "place_of_issue": "Dubai",
#             "valid_until": "23/07/2025",
#             "uid_number": "84193034",
#             "full_name": "Ms. ANISHA THAPA MAGAR",
#             "nationality": "NEPAL",
#             "place_of_birth": "KASKI",
#             "date_of_birth": "26/02/2002",
#             "passport_number": "PA0272457",
#             "profession": "NURSE ASSISTANT"
#         }
#     ]
# }
